# %% [markdown]
# # GPU Configuration

# %%
# !sudo add-apt-repository ppa:graphics-drivers/ppa
# !sudo apt-get update
# !sudo apt-get install nvidia-driver-450
# Out:
#  Fresh drivers from upstream, currently shipping Nvidia.
#
# ## Current releases
#
# Current production branch release: 535.43.02 (x86_64)
# Current new feature branch release: 530.41.03 (x86_64)
# Current beta release: 535.43.02 (x86_64)
#
# ## Legacy releases
#
# 470.182.03 (x86_64) - GKxxx “Kepler” GPUs
# 390.157 (x86 / x86_64 / ARM) - GF1xx “Fermi” GPUs (*​)
# 340.108 (x86 / x86_64) - GeForce 8 and 9 series GPUs (*​)
# 304.137 (x86 / x86_64) - GeForce 6 and 7 series GPUs (*​)
# 173.14.39 (x86 / x86_64) - GeForce 5 series GPUs (*​)
# 96.43.23 (x86 / x86_64) - GeForce 2 through GeForce 4 series GPUs (*​)
# 71.86.15 (x86 / x86_64) - Riva TNT, TNT2, GeForce, and some GeForce 2 GPUs (*​)
# (*​) These releases are no longer being maintained. Please see Support timeframes for Unix legacy GPU releases for more details. https://nvidia.custhelp.com/app/answers/detail/a_id/3142
#
# ## What we're working on right now:
#
# - Normal driver updates
# ...

# %% [markdown]
# # Blender Installation

# %%
import os

blender_version = '3.5.1'
blender_url = "https://ftp.nluug.nl/pub/graphics/blender/release/Blender3.5/blender-3.5.1-linux-x64.tar.xz"
base_url = os.path.basename(blender_url)

# !mkdir $blender_version
# !wget -nc $blender_url
# !tar -xkf $base_url -C ./$blender_version --strip-components=1
# Out:
# mkdir: cannot create directory ‘3.5.1’: File exists
# File ‘blender-3.5.1-linux-x64.tar.xz’ already there; not retrieving.
#
# tar: license/THIRD-PARTY-LICENSES.txt: Cannot open: File exists
# tar: license/jemalloc.txt: Cannot open: File exists
# tar: license/bmonofont-i18n.ttf.txt: Cannot open: File exists
# tar: license/BSD-3-Clause.txt: Cannot open: File exists
# tar: license/Apache-2.0.txt: Cannot open: File exists
# tar: license/MIT.txt: Cannot open: File exists
# tar: license/OpenSSL.txt: Cannot open: File exists
# tar: license/FTL.txt: Cannot open: File exists
# tar: license/BSL-1.0.txt: Cannot open: File exists
# tar: license/Python.txt: Cannot open: File exists
# tar: license/droidsans.ttf.txt: Cannot open: File exists
# tar: license/bfont.ttf.txt: Cannot open: File exists
# tar: license/GPL-3.0.txt: Cannot open: File exists
# tar: license/OpenColorIO.txt: Cannot open: File exists
# tar: license/GPL-license.txt: Cannot open: File exists
# ...

# %% [markdown]
# # Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Render

# %%
# !./$blender_version/blender --background -b '/content/drive/MyDrive/Backend-contents-generation/virtual_studio/virtual_studio.blend' -P /content/drive/MyDrive/Backend-contents-generation/scripts/main.py -- -fbx_file /content/drive/MyDrive/Backend-contents-generation/graphic_dtb/dog.fbx
# Out:
# Blender 3.5.1 (hash e1ccd9d4a1d3 built 2023-04-24 23:31:15)
# Blender 3.5.1 (hash e1ccd9d4a1d3 built 2023-04-24 23:31:15)
# Read blend: /content/drive/MyDrive/Backend-contents-generation/virtual_studio/virtual_studio.blend
# FBX version: 7400
# Fra:1 Mem:67.33M (Peak 68.41M) | Time:00:01.30 | Syncing Plane
# Fra:1 Mem:67.36M (Peak 68.41M) | Time:00:02.26 | Syncing Camera
# Fra:1 Mem:67.36M (Peak 68.41M) | Time:00:02.26 | Syncing Area - Key Light
# Fra:1 Mem:67.36M (Peak 68.41M) | Time:00:02.26 | Syncing Area - Fill Light
# Fra:1 Mem:67.36M (Peak 68.41M) | Time:00:02.26 | Syncing Atmosphere
# Fra:1 Mem:67.38M (Peak 68.41M) | Time:00:02.79 | Syncing dog
# Fra:1 Mem:67.39M (Peak 68.41M) | Time:00:02.79 | Syncing dog mesh
# Fra:1 Mem:67.60M (Peak 68.41M) | Time:00:03.99 | Rendering 1 / 32 samples
# Fra:1 Mem:67.45M (Peak 68.41M) | Time:00:05.24 | Rendering 26 / 32 samples
# Fra:1 Mem:67.45M (Peak 68.41M) | Time:00:05.27 | Rendering 32 / 32 samples
# Append frame 1
# ...

# %%
# !nvidia-smi
# Out:
# Wed Jul  5 04:24:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
